# %%
from sklearn import datasets

dataset = datasets.load_iris()
X = dataset.data
y = dataset.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %%
from api.scratch import DecisionTreeClassifier, RandomForestClassifier, XGBoostClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
from sklearn.metrics import accuracy_score, precision_score, recall_score
y_pred = model.predict(X_test)
print("Accuracy: ", accuracy_score(y_pred, y_test))
print("Precision: ", precision_score(y_pred, y_test, average='macro'))
print("Recall: ", recall_score(y_pred, y_test, average='macro'))
# Out:
# Accuracy:  0.8888888888888888
# Precision:  0.8854700854700854
# Recall:  0.9242424242424242

# %%
model = RandomForestClassifier(n_estimators=10)
model.fit(X_train, y_train)

from sklearn.metrics import accuracy_score, precision_score, recall_score
y_pred = model.predict(X_test)
print("Accuracy: ", accuracy_score(y_pred, y_test))
print("Precision: ", precision_score(y_pred, y_test, average='macro'))
print("Recall: ", recall_score(y_pred, y_test, average='macro'))
# Out:
# Accuracy:  0.8888888888888888
# Precision:  0.8880844645550529
# Recall:  0.9076923076923077

# %%
model = XGBoostClassifier()
model.fit(X_train, y_train)
from sklearn.metrics import accuracy_score, precision_score, recall_score
y_pred = model.predict(X_test)
print("Accuracy: ", accuracy_score(y_pred, y_test))
print("Precision: ", precision_score(y_pred, y_test, average='macro'))
print("Recall: ", recall_score(y_pred, y_test, average='macro'))
# Out:
# Accuracy:  0.9333333333333333
# Precision:  0.9299145299145298
# Recall:  0.9285714285714285

# %%
import pickle

with open("/Users/sudhirsingh/PyCharmProjects/classification/models/xg.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
import os
os.listdir('.')
# Out:
# ['requirements.txt',
#  'endpoint',
#  '.venv',
#  'api',
#  'docker-compose.yml',
#  'main.py',
#  '.idea']

# %%
with open("./api/models/xg.pkl", "rb") as f:
    model = pickle.load(f)

# %%
def input(model, a,b,c,d):
    import numpy as np
    return str(dataset.target_names[int(model.predict(np.array([[a, b, c, d]]))[0])])

# %%
input(model, 2,3,4,1)
# Out:
# 'versicolor'
